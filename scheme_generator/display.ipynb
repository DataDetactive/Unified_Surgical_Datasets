# %%
import json
from pathlib import Path
import os

# %%
def integrate_annotations_into_unified_data(unified_data, cholect80_path):
    phase_annotations_path = Path(cholect80_path) / 'phase_annotations'
    
    for phase_file in phase_annotations_path.glob('*.txt'):
        video_id = "VID" + phase_file.stem.split('video')[1].split('-')[0].zfill(2)
        phases = parse_annotation_file(phase_file)

        for frame_id, phase in phases.items():
            if video_id not in unified_data:
                unified_data[video_id] = {"annotations": {}}
            if frame_id not in unified_data[video_id]["annotations"]:
                unified_data[video_id]["annotations"][frame_id] = {"categories": {}, "qa": [], "tools": []}
            
            unified_data[video_id]["annotations"][frame_id]["phase"] = phase


    return unified_data

# %%
def display_frame_annotations(frame_data):
    """
    Displays annotations for a specific frame, including phase information correctly.
    """
    print("    Categories:")
    for category, items in frame_data.get("categories", {}).items():
        items_str = ', '.join(str(item) for item in items if item is not None)
        print(f"      {category.capitalize()}: {items_str if items_str else 'N/A'}")
    
    # Display the phase directly
    phase = frame_data.get("phase", "N/A")
    print(f"    Phase: {phase}")
    

    # Continue with Q&A display as before
    if "qa" in frame_data:
        print("    Q&A:")
        for qa in frame_data["qa"]:
            print(f"      Question: {qa.get('question')}")
            for answer in qa.get("answers", []):
                print(f"        Answer: {answer}")
    print("")  # Newline for better readability

# %% [markdown]
# ## Integrate CholecT50

# %%
json_file_path = '/media/telecom/77F7-D47D/unify_data/data.json'

cholect50_root_path = '/home/telecom/Downloads/CholecT50'
cholect50_labels_path = os.path.join(cholect50_root_path, 'labels')  
label_mapping_path = os.path.join(cholect50_root_path, 'label_mapping.txt')

label_mapping = {}
with open(label_mapping_path, 'r') as file:
    for line in file:
        parts = [part.strip() for part in line.strip().split(',')]
        
        try:
            triplet_id, instrument_id, verb_id, target_id, _, _ = [int(part) for part in parts]
            label_mapping[triplet_id] = {
                "instrument_id": instrument_id,
                "verb_id": verb_id,
                "target_id": target_id
            }
        except ValueError:
            print(f"Skipping line due to conversion issue: {line}")
            continue


def get_category_by_id(category_map, category_id):
    return category_map.get(category_id, "")

def build_categories_dict(categories):
    return {
        "instrument": {int(k): v for k, v in categories['instrument'].items()},
        "verb": {int(k): v for k, v in categories['verb'].items()},
        "target": {int(k): v for k, v in categories['target'].items()}
    }

def unify_cholect50_to_schema(cholect50_data, video_id, categories_dict):
    annotations = {}

    for frame_id, frame_annotations in cholect50_data['annotations'].items():
        frame_categories = {
            "instruments": [],
            "verbs": [],
            "targets": [],
        }

        for triplet in frame_annotations:
            triplet_id = triplet[0]
            triplet_mapping = label_mapping.get(triplet_id, {})

            instrument = get_category_by_id(categories_dict.get("instrument", {}), triplet_mapping.get("instrument_id", ""))
            verb = get_category_by_id(categories_dict.get("verb", {}), triplet_mapping.get("verb_id", ""))
            target = get_category_by_id(categories_dict.get("target", {}), triplet_mapping.get("target_id", ""))
            

            frame_categories["instruments"].append(instrument if instrument is not None else "")
            frame_categories["verbs"].append(verb if verb is not None else "")
            frame_categories["targets"].append(target if target is not None else "")

            # Extract bounding box coordinates
            bbox = {
                'x1': triplet[2],
                'y1': triplet[3],
                'width': triplet[4],
                'height': triplet[5]
            }

            frame_categories["instruments"].append(instrument)
            frame_categories["verbs"].append(verb)
            frame_categories["targets"].append(target)
            #frame_categories["phases"].append(phase_name)

            

        annotations[str(frame_id)] = {
            # ... specify bbox coordinates...
            "categories": frame_categories
        }
    
    video_data = {
        video_id: {
            "annotations": annotations
        }
    }
    
    return video_data

unified_data = {}

categories_dict = {}

for label_file in os.listdir(cholect50_labels_path):
    if label_file.endswith('.json'):
        label_file_path = os.path.join(cholect50_labels_path, label_file)
        
        with open(label_file_path, 'r') as file:
            cholect50_data = json.load(file)

        if not categories_dict:
            categories_dict = build_categories_dict(cholect50_data['categories'])

        video_id = label_file.replace('.json', '')
        
        video_data = unify_cholect50_to_schema(cholect50_data, video_id, categories_dict)
        unified_data.update(video_data)

with open(json_file_path, 'w') as outfile:
    json.dump(unified_data, outfile, indent=4)

print(f"Unified dataset has been saved to {json_file_path}")
# Out:
# Skipping line due to conversion issue: # IVT, I, V, T, IV, IT
#
# Unified dataset has been saved to /media/telecom/77F7-D47D/unify_data/data.json

# %% [markdown]
# ## Integrate SSG-VQA

# %%
def parse_qa_txt_file(qa_file_path):
    qa_data = []
    with open(qa_file_path, 'r', encoding='utf-8') as file:
        for line in file:
            question, *answers = line.strip().split('|')
            if not question.endswith('?'):
                question += '?'
            qa_data.append({"question": question, "answers": [answer.strip() for answer in answers]})
    return qa_data

def integrate_qa_into_annotations(unified_data, video_id, frame_id, qa_data):
    if video_id not in unified_data:
        unified_data[video_id] = {"annotations": {}}
    if frame_id not in unified_data[video_id]["annotations"]:
        unified_data[video_id]["annotations"][frame_id] = {"categories": {}, "qa": []}

    # If 'qa' key doesn't exist within the frame, initialize it as an empty list
    frame_annotation = unified_data[video_id]["annotations"][frame_id]
    frame_annotation.setdefault("qa", [])

    frame_annotation["qa"].extend(qa_data)


def integrate_all_qa(sqa_path, unified_data):
    for video_dir in os.listdir(sqa_path):
        video_path = os.path.join(sqa_path, video_dir)
        if os.path.isdir(video_path):
            for qa_file in os.listdir(video_path):
                frame_id, _ = os.path.splitext(qa_file)
                qa_file_path = os.path.join(video_path, qa_file)
                qa_data = parse_qa_txt_file(qa_file_path)
                integrate_qa_into_annotations(unified_data, video_dir.upper(), frame_id, qa_data)

sqa_path = '/home/telecom/SSG-VQA/data/qa_txt' 
unified_json_file_path = '/media/telecom/77F7-D47D/unify_data/data.json' 

unified_data = {}
with open(unified_json_file_path, 'r') as file:
    unified_data = json.load(file)

integrate_all_qa(sqa_path, unified_data)

with open(unified_json_file_path, 'w') as file:
    json.dump(unified_data, file, indent=4)

# %% [markdown]
# ## CholechT80

# %%
# Paths
cholect80_path = '/media/telecom/77F7-D47D/cholec80'  
unified_json_file_path = '/media/telecom/77F7-D47D/unify_data/data.json'

# %%
def parse_annotation_file(file_path):
    """
    Parses a phase or tool annotation file and returns a dictionary keyed by frame ID.
    Each frame will have either a phase or a tool annotation.
    """
    annotations = {}
    with open(file_path, 'r', encoding='utf-8') as file:
        next(file)  
        for line in file:
            parts = line.strip().split('\t')
            frame_id, annotation = parts[0], parts[1]
            annotations[frame_id] = annotation
    return annotations

# %%
def integrate_annotations_into_unified_data(unified_data, cholect80_path):
    phase_annotations_path = Path(cholect80_path) / 'phase_annotations'
    tool_annotations_path = Path(cholect80_path) / 'tool_annotations'
    
    for phase_file in phase_annotations_path.glob('*.txt'):
        video_id = "VID" + phase_file.stem.split('video')[1].split('-')[0].zfill(2)
        phases = parse_annotation_file(phase_file)

        for frame_id, phase in phases.items():
            if video_id not in unified_data:
                unified_data[video_id] = {"annotations": {}}
            if frame_id not in unified_data[video_id]["annotations"]:
                unified_data[video_id]["annotations"][frame_id] = {"categories": {}, "qa": [], "tools": []}
            unified_data[video_id]["annotations"][frame_id]["phase"] = phase
    
    for tool_file in tool_annotations_path.glob('*.txt'):
        video_id = "VID" + tool_file.stem.split('video')[1].split('-')[0].zfill(2)
        tools = parse_annotation_file(tool_file)

        for frame_id, tool in tools.items():
            if video_id not in unified_data:
                unified_data[video_id] = {"annotations": {}}
            if frame_id not in unified_data[video_id]["annotations"]:
                unified_data[video_id]["annotations"][frame_id] = {"categories": {}, "qa": [], "phase": ""}
            if "tools" not in unified_data[video_id]["annotations"][frame_id]:
                unified_data[video_id]["annotations"][frame_id]["tools"] = []
            unified_data[video_id]["annotations"][frame_id]["tools"].append(tool)

    return unified_data

# %%
with open(unified_json_file_path, 'r') as file:
    unified_data = json.load(file)

unified_data = integrate_annotations_into_unified_data(unified_data, cholect80_path)

with open(unified_json_file_path, 'w') as file:
    json.dump(unified_data, file, indent=4)

# %%
def parse_tool_annotations(file_path):
    tool_usage = {}
    with open(file_path, 'r', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile, delimiter='\t')
        for row in reader:
            frame_id = row['Frame']
            present_tools = [tool for tool, presence in row.items() if tool != 'Frame' and presence == '1']
            tool_usage[frame_id] = present_tools
    return tool_usage

def integrate_tools_into_unified_data(unified_data, video_id, tool_usage):
    for frame_id, tools in tool_usage.items():
        if video_id not in unified_data:
            unified_data[video_id] = {"annotations": {}}
        if frame_id not in unified_data[video_id]["annotations"]:
            unified_data[video_id]["annotations"][frame_id] = {"categories": {}, "qa": []}
        
        unified_data[video_id]["annotations"][frame_id]["tools"] = tools

    return unified_data

# %% [markdown]
# ### draft

# %%
def parse_phase_file(phase_file_path):
    """
    Parses a phase annotation file and returns a dictionary of phases keyed by frame ID.
    """
    phases = {}
    with open(phase_file_path, 'r', encoding='utf-8') as file:
        next(file)  # Skip the header line
        for line in file:
            parts = line.strip().split('\t')  # Assuming tab-separated values
            if len(parts) == 2:
                frame_id, phase = parts
                phases[frame_id] = phase
    return phases


def update_annotations(unified_data, video_id, phase_annotations, tool_annotations):
    """
    Updates the unified data with phase and tool annotations for a specific video.
    """
    if video_id not in unified_data:
        unified_data[video_id] = {"annotations": {}}

    for frame_id, phase in phase_annotations.items():
        if frame_id not in unified_data[video_id]["annotations"]:
            unified_data[video_id]["annotations"][frame_id] = {"categories": {}, "qa": [], "phases": [], "tools": []}
        unified_data[video_id]["annotations"][frame_id]["phases"].extend(phase)
    
    for frame_id, tools in tool_annotations.items():
        if frame_id not in unified_data[video_id]["annotations"]:
            unified_data[video_id]["annotations"][frame_id] = {"categories": {}, "qa": [], "phases": [], "tools": []}
        unified_data[video_id]["annotations"][frame_id]["tools"].extend(tools)

def integrate_cholect80(cholect80_path, unified_data):
    """
    Integrates CholecT80 data (both phase and tool annotations) into the unified dataset.
    """
    for video_num in range(1, 81):
        video_id = f"video{video_num:02d}"
        phase_file_path = Path(cholect80_path) / "phase_annotations" / f"{video_id}-phase.txt"
        tool_file_path = Path(cholect80_path) / "tool_annotations" / f"{video_id}-tool.txt"

        phase_annotations = parse_annotation_file(phase_file_path) if phase_file_path.exists() else {}
        tool_annotations = parse_annotation_file(tool_file_path) if tool_file_path.exists() else {}
        
        update_annotations(unified_data, video_id, phase_annotations, tool_annotations)

    return unified_data

def integrate_phases_into_unified_data(unified_data, video_id, phases):
    """
    Integrates phase annotations into the unified data for the specified video.
    """
    if video_id not in unified_data:
        unified_data[video_id] = {"annotations": {}}

    for frame_id, phase in phases.items():
        if frame_id not in unified_data[video_id]["annotations"]:
            unified_data[video_id]["annotations"][frame_id] = {"categories": {}, "qa": []}
        
        unified_data[video_id]["annotations"][frame_id]["phase"] = phase  

    return unified_data

with open(unified_json_file_path, 'r') as file:
    unified_data = json.load(file)

unified_data = integrate_cholect80(cholect80_path, unified_data)


phase_annotations_path = Path(cholect80_path) / 'phase_annotations'
for phase_file in phase_annotations_path.glob('*.txt'):
    video_id = phase_file.stem  
    phases = parse_phase_file(phase_file)
    unified_data = integrate_phases_into_unified_data(unified_data, video_id, phases)

with open(unified_json_file_path, 'w') as file:
    json.dump(unified_data, file, indent=4)

# %% [markdown]
# ## Display with Vid ID and frame

# %%
def display_annotations(dataset, video_id, frame_id=None):
    """
    Display annotations for a specific video and optionally a specific frame within that video.
    """
    video_data = dataset.get(video_id, {})
    if not video_data:
        print(f"No data found for video ID: {video_id}")
        return

    annotations = video_data.get("annotations", {})
    if frame_id:
        frame_data = annotations.get(str(frame_id), {})
        if not frame_data:
            print(f"No data found for frame ID: {frame_id} in video ID: {video_id}")
            return
        print(f"Annotations for Video ID: {video_id}, Frame ID: {frame_id}:")
        display_frame_annotations(frame_data)
    else:
        for frame_id, frame_data in annotations.items():
            print(f"Annotations for Video ID: {video_id}, Frame ID: {frame_id}:")
            display_frame_annotations(frame_data)


def display_frame_annotations(frame_data):
    tool_names = ["Grasper", "Bipolar", "Hook", "Scissors", "Clipper", "Irrigator", "SpecimenBag"]
    
    print("    Categories:")
    for category, items in frame_data.get("categories", {}).items():
        items_str = ', '.join(str(item) for item in items if item is not None)
        print(f"      {category.capitalize()}: {items_str if items_str else 'N/A'}")
    
    phase = frame_data.get("phase", "N/A")
    print(f"    Phase: {phase}")

    tools_presence = frame_data.get("tools", [])
    if tools_presence:
        present_tools = [name for index, present in enumerate(tools_presence) if present == 1]
        if present_tools:
            print("    Tools:")
            print(f"      {', '.join(present_tools)}")
        else:
            print("    Tools: None")
    else:
        print("    Tools: N/A")

    if "qa" in frame_data:
        print("    Q&A:")
        for qa in frame_data["qa"]:
            print(f"      Question: {qa.get('question')}")
            answers = ', '.join(qa.get("answers", []))
            print(f"        Answers: {answers}")
    print("")  


unified_json_file_path = '/media/telecom/77F7-D47D/unify_data/data.json' 

with open(unified_json_file_path, 'r') as file:
    dataset = json.load(file)

video_id = "VID01"
frame_id = "0"  #  None for all frames 

display_annotations(dataset, video_id, frame_id)
# Out:
# Annotations for Video ID: VID01, Frame ID: 0:
#     Categories:
#       Instruments: grasper, grasper
#       Verbs: grasp, grasp
#       Targets: gallbladder, gallbladder
#     Phase: Preparation
#     Tools: None

# %%
tool_annotations_file = '/media/telecom/77F7-D47D/cholec80/tool_annotations/video01-tool.txt'  # Update with your actual file path
tool_usage = parse_tool_annotations(tool_annotations_file)

unified_data = integrate_tools_into_unified_data(unified_data, "VID01", tool_usage)

display_annotations(unified_data, "VID01", "1")
# Out:
# Annotations for Video ID: VID01, Frame ID: 1:
#     Categories:
#       Instruments: grasper
#       Verbs: grasp
#       Targets: gallbladder
#     Phase: Preparation
#     Tools: N/A
#     Triplets:
#       (grasper, grasp, gallbladder)
#     Q&A:
#       Question: Which anatomical structures are present?
#         Answer: abdominal_wall_cavity, liver, gut, omentum, gallbladder
#       Question: Which tools are present?
#         Answer: grasper
#       Question: What is the grasper doing?
#         Answer: grasp
#       Question: Which tool is operating on gallbladder?
#         Answer: grasper
#       Question: What anatomy is at the top-left of the frame ?
#         Answer: abdominal_wall_cavity
#         Answer: [67.0, 85.5]
#       Question: What anatomy is at the top-mid of the frame ?
#         Answer: liver
#         Answer: [212.0, 119.5]
#       Question: What number of objects are both below the red top-left object and above the top-mid liver object?
#         Answer: 0
#         Answer: single_and.json
#         Answer: count
#         Answer: NA
#       Question: How many anatomys are both right of the abdominal_wall_cavity thing and to the left of the top-mid liver thing?
#         Answer: 1
#         Answer: single_and.json
#         Answer: count
#         Answer: NA
#       Question: How many things are both right of the abdominal_wall_cavity thing and on the left side of the top-mid liver object?
#         Answer: 2
#         Answer: single_and.json
#         Answer: count
#         Answer: NA
#       Question: What number of red anatomys are both to the right of the abdominal_wall_cavity object and left of the top-mid liver thing?
#         Answer: 0
#         Answer: single_and.json
#         Answer: count
#         Answer: NA
#       Question: What name is the thing that is within the silver top-mid thing and to the right of the white anatomy?
#         Answer: liver
#         Answer: single_and.json
#         Answer: query_component
#         Answer: NA
#       Question: What is the name of the anatomy that is both to the right of the abdominal_wall_cavity thing and to the left of the yellow thing?
#         Answer: gallbladder
#         Answer: single_and.json
#         Answer: query_component
#         Answer: NA
#       Question: What is the name of the anatomy that is both right of the red top-left abdominal_wall_cavity anatomy and to the left of the yellow object?
#         Answer: gallbladder
#         Answer: single_and.json
#         Answer: query_component
#         Answer: NA
#       Question: There is a object that is below the grasper instrument and above the yellow thing?; what is its name?
#         Answer: abdominal_wall_cavity
#         Answer: single_and.json
#         Answer: query_component
#         Answer: NA
#       Question: What is the color of the thing that is both below the top-left abdominal_wall_cavity anatomy and on the left side of the gut thing?
#         Answer: yellow
#         Answer: single_and.json
#         Answer: query_color
#         Answer: NA
#       Question: There is a object that is both within the silver top-mid grasper instrument and within the gut object?; what is its color?
#         Answer: brown
#         Answer: single_and.json
#         Answer: query_color
#         Answer: NA
#       Question: What is the color of the anatomy that is both within the silver top-mid grasper instrument and within the gut object?
#         Answer: brown
#         Answer: single_and.json
#         Answer: query_color
#         Answer: NA
#       Question: There is a anatomy that is both below the top-left object and within the gut thing?; what is its color?
#         Answer: yellow
#         Answer: single_and.json
#         Answer: query_color
#         Answer: NA
#       Question: What number of silver grasper things are there?
#         Answer: 1
#         Answer: zero_hop.json
#         Answer: count
#         Answer: NA
#       Question: How many brown bottom-left specimenbag anatomys are there?
#         Answer: 0
#         Answer: zero_hop.json
#         Answer: count
#         Answer: NA
#       Question: What number of brown anatomys are there?
#         Answer: 1
#         Answer: zero_hop.json
#         Answer: count
#         Answer: NA
#       Question: There is a liver thing; how many abdominal_wall_cavity anatomys are grasped by it?
#         Answer: 0
#         Answer: one_hop.json
#         Answer: count
#         Answer: relate_actional
#       Question: What number of gut anatomys are below the liver object?
#         Answer: 1
#         Answer: one_hop.json
#         Answer: count
#         Answer: relate_spatial
#       Question: There is a top-mid liver object; are there any bottom-right anatomys grasped by it?
#         Answer: False
#         Answer: one_hop.json
#         Answer: exist
#         Answer: relate_actional
#       Question: There is a top-mid liver thing; are there any anatomys below it?
#         Answer: True
#         Answer: one_hop.json
#         Answer: exist
#         Answer: relate_spatial
#       Question: The top-mid anatomy that is grasped by the top-mid grasper instrument is what color?
#         Answer: white
#         Answer: one_hop.json
#         Answer: query_color
#         Answer: relate_actional
#       Question: There is a top-mid thing that is right of the top-mid grasper instrument; what color is it?
#         Answer: brown
#         Answer: one_hop.json
#         Answer: query_color
#         Answer: relate_spatial
#       Question: There is a object on the right side of the liver anatomy; what type is it?
#         Answer: anatomy
#         Answer: one_hop.json
#         Answer: query_type
#         Answer: relate_spatial
#       Question: There is a silver grasper thing that is to the left of the liver anatomy; what type is it?
#         Answer: instrument
#         Answer: one_hop.json
#         Answer: query_type
#         Answer: relate_spatial
#       Question: There is a red object to the left of the silver top-mid grasper thing; what is it?
#         Answer: abdominal_wall_cavity
#         Answer: one_hop.json
#         Answer: query_component
#         Answer: relate_spatial
#       Question: There is a top-mid anatomy that is right of the silver top-mid grasper object; what is it?
#         Answer: liver
#         Answer: one_hop.json
#         Answer: query_component
#         Answer: relate_spatial
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Analyse

# %%
def analyze_phase_transitions(unified_data, video_id):
    previous_phase = None
    transitions = []

    annotations = unified_data[video_id]["annotations"]
    for frame_id in sorted(annotations.keys(), key=lambda x: int(x)):
        current_phase = annotations[frame_id].get("phase")
        if current_phase != previous_phase:
            transitions.append((frame_id, current_phase))
            previous_phase = current_phase
    
    return transitions

# Example usage
transitions = analyze_phase_transitions(unified_data, "VID31")
print("Phase Transitions in VID31:")
for frame_id, phase in transitions:
    print(f"At frame {frame_id}, transitioned to '{phase}' phase.")
# Out:
# Phase Transitions in VID31:
# At frame 0, transitioned to 'Preparation' phase.
# At frame 4150, transitioned to 'CalotTriangleDissection' phase.
# At frame 78075, transitioned to 'ClippingCutting' phase.
# At frame 89075, transitioned to 'GallbladderDissection' phase.
# At frame 94675, transitioned to 'GallbladderPackaging' phase.
# At frame 97150, transitioned to 'CleaningCoagulation' phase.
# At frame 98525, transitioned to 'GallbladderRetraction' phase.

# %%
def analyze_all_phase_transitions(unified_data):
    all_transitions = {}
    l= []
    for video_id in unified_data.keys():
        previous_phase = None
        transitions = []

        annotations = unified_data[video_id]["annotations"]
        for frame_id in sorted(annotations.keys(), key=lambda x: int(x)):
            current_phase = annotations[frame_id].get("phase")
            if current_phase != previous_phase:
                transitions.append((frame_id, current_phase))
                previous_phase = current_phase
        
        l.append(frame_id)
        
        all_transitions[video_id] = transitions
    print(l)
    return all_transitions 

# Example usage
all_transitions = analyze_all_phase_transitions(unified_data)

for video_id, transitions in all_transitions.items():
    print(f"Phase Transitions in {video_id}:")
    for frame_id, phase in transitions:
        print(f"  At frame {frame_id}, transitioned to '{phase}' phase.")
    print("\n")
# Out:
# ['98625', '2219', '63300', '2123', '40875', '18475', '38050', '65800', '52650', '42700', '46825', '33900', '70975', '55550', '45850', '2176', '58600', '40850', '59050', '43325', '29850', '59675', '45600', '52100', '27350', '51451', '2145', '58750', '92800', '1706', '43100', '56475', '41775', '45850', '43725', '44325', '53825', '24525', '52900', '73600', '53225', '37975', '27250', '49300', '49150', '85350', '48075', '50800', '48550', '38300', '2358', '2532', '1531', '2532', '2838', '1531', '1634', '1634', '2360', '2839', '145700', '113925', '67550', '80500', '77575', '73925', '32600', '60600', '36225', '78175', '84675', '41325', '31450', '49375', '29975', '73125', '32675', '33075', '30801', '77000', '82075', '77500', '41175', '25925', '149825', '26150', '110225', '85825', '59950', '58825', '114375', '62875', '77650', '66225', '62550', '43325', '70975', '145700', '38050', '58600', '53825', '113925', '37975', '67550', '43725', '80500', '27250', '24525', '42700', '51451', '73925', '32600', '48550', '60600', '36225', '31450', '38300', '40875', '49375', '53225', '44325', '52100', '29975', '58750', '73125', '98625', '52900', '32675', '33075', '52650', '59675', '30801', '77000', '41175', '55550', '77575', '92800', '59050', '78175', '84675', '41325', '56475', '45850', '41775', '27350', '73600', '49150', '82075', '77500', '25925', '45850', '65800', '149825', '26150', '63300', '110225', '50800', '85825', '59950', '46825', '45600', '58825', '49300', '114375', '29850', '62875', '77650', '33900', '40850', '48075', '66225', '62550', '18475', '85350', '43100', '43325', '70975', '145700', '38050', '58600', '53825', '113925', '37975', '67550', '43725', '80500', '77575', '27250', '24525', '92800', '42700', '51451', '73925', '32600', '59050', '48550', '60600', '36225', '78175', '84675', '41325', '31450', '38300', '40875', '49375', '53225', '56475', '44325', '52100', '29975', '58750', '73125', '98625', '52900', '45850', '41775', '32675', '33075', '27350', '73600', '52650', '59675', '30801', '49150', '77000', '82075', '77500', '41175', '25925', '45850', '65800', '55550', '149825', '26150', '63300', '110225', '50800', '85825', '59950', '46825', '45600', '58825', '49300', '114375', '29850', '62875', '77650', '33900', '40850', '48075', '66225', '62550', '18475', '85350', '43100']
# Phase Transitions in VID31:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 4150, transitioned to 'CalotTriangleDissection' phase.
#   At frame 78075, transitioned to 'ClippingCutting' phase.
#   At frame 89075, transitioned to 'GallbladderDissection' phase.
#   At frame 94675, transitioned to 'GallbladderPackaging' phase.
#   At frame 97150, transitioned to 'CleaningCoagulation' phase.
#   At frame 98525, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID103:
#
#
# Phase Transitions in VID60:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 8075, transitioned to 'CalotTriangleDissection' phase.
#   At frame 52525, transitioned to 'ClippingCutting' phase.
#   At frame 54625, transitioned to 'GallbladderDissection' phase.
#   At frame 57275, transitioned to 'CleaningCoagulation' phase.
#   At frame 59625, transitioned to 'GallbladderPackaging' phase.
#   At frame 62325, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID92:
#
#
# Phase Transitions in VID23:
#   At frame 0, transitioned to 'CalotTriangleDissection' phase.
#   At frame 15675, transitioned to 'ClippingCutting' phase.
#   At frame 17725, transitioned to 'GallbladderDissection' phase.
#   At frame 26650, transitioned to 'GallbladderPackaging' phase.
#   At frame 28500, transitioned to 'CleaningCoagulation' phase.
#   At frame 38600, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID78:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1100, transitioned to 'CalotTriangleDissection' phase.
#   At frame 8300, transitioned to 'ClippingCutting' phase.
#   At frame 9900, transitioned to 'GallbladderDissection' phase.
#   At frame 13950, transitioned to 'CleaningCoagulation' phase.
#   At frame 15775, transitioned to 'GallbladderPackaging' phase.
#   At frame 17350, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID04:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 7275, transitioned to 'CalotTriangleDissection' phase.
#   At frame 22450, transitioned to 'ClippingCutting' phase.
#   At frame 24100, transitioned to 'GallbladderDissection' phase.
#   At frame 31000, transitioned to 'GallbladderPackaging' phase.
#   At frame 31950, transitioned to 'CleaningCoagulation' phase.
#   At frame 34325, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID57:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 3625, transitioned to 'CalotTriangleDissection' phase.
#   At frame 28125, transitioned to 'ClippingCutting' phase.
#   At frame 33050, transitioned to 'GallbladderDissection' phase.
#   At frame 56175, transitioned to 'CleaningCoagulation' phase.
#   At frame 59750, transitioned to 'GallbladderPackaging' phase.
#   At frame 61775, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID35:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1325, transitioned to 'CalotTriangleDissection' phase.
#   At frame 30275, transitioned to 'ClippingCutting' phase.
#   At frame 36600, transitioned to 'GallbladderDissection' phase.
#   At frame 44775, transitioned to 'GallbladderPackaging' phase.
#   At frame 46475, transitioned to 'CleaningCoagulation' phase.
#   At frame 51550, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID14:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 800, transitioned to 'CalotTriangleDissection' phase.
#   At frame 14750, transitioned to 'ClippingCutting' phase.
#   At frame 15850, transitioned to 'GallbladderDissection' phase.
#   At frame 33600, transitioned to 'GallbladderPackaging' phase.
#   At frame 37775, transitioned to 'GallbladderRetraction' phase.
#   At frame 39625, transitioned to 'CleaningCoagulation' phase.
#
#
# Phase Transitions in VID65:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 6225, transitioned to 'CalotTriangleDissection' phase.
#   At frame 28600, transitioned to 'ClippingCutting' phase.
#   At frame 31300, transitioned to 'GallbladderDissection' phase.
#   At frame 43950, transitioned to 'GallbladderPackaging' phase.
#   At frame 45900, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID73:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 2425, transitioned to 'CalotTriangleDissection' phase.
#   At frame 18175, transitioned to 'ClippingCutting' phase.
#   At frame 20775, transitioned to 'GallbladderDissection' phase.
#   At frame 27950, transitioned to 'GallbladderPackaging' phase.
#   At frame 29125, transitioned to 'CleaningCoagulation' phase.
#   At frame 32100, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID02:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 12025, transitioned to 'CalotTriangleDissection' phase.
#   At frame 31325, transitioned to 'ClippingCutting' phase.
#   At frame 39525, transitioned to 'GallbladderDissection' phase.
#   At frame 63425, transitioned to 'GallbladderPackaging' phase.
#   At frame 64950, transitioned to 'CleaningCoagulation' phase.
#   At frame 69475, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID40:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 6550, transitioned to 'CalotTriangleDissection' phase.
#   At frame 33425, transitioned to 'ClippingCutting' phase.
#   At frame 37950, transitioned to 'GallbladderDissection' phase.
#   At frame 50175, transitioned to 'GallbladderPackaging' phase.
#   At frame 52750, transitioned to 'CleaningCoagulation' phase.
#   At frame 54450, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID48:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 3500, transitioned to 'CalotTriangleDissection' phase.
#   At frame 26650, transitioned to 'ClippingCutting' phase.
#   At frame 29150, transitioned to 'GallbladderDissection' phase.
#   At frame 38775, transitioned to 'GallbladderPackaging' phase.
#   At frame 42750, transitioned to 'CleaningCoagulation' phase.
#   At frame 43875, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID110:
#
#
# Phase Transitions in VID05:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1600, transitioned to 'CalotTriangleDissection' phase.
#   At frame 25375, transitioned to 'ClippingCutting' phase.
#   At frame 32600, transitioned to 'GallbladderDissection' phase.
#   At frame 38600, transitioned to 'GallbladderPackaging' phase.
#   At frame 41575, transitioned to 'CleaningCoagulation' phase.
#   At frame 44350, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID74:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 2175, transitioned to 'CalotTriangleDissection' phase.
#   At frame 12525, transitioned to 'ClippingCutting' phase.
#   At frame 15750, transitioned to 'GallbladderDissection' phase.
#   At frame 33425, transitioned to 'CleaningCoagulation' phase.
#   At frame 35675, transitioned to 'GallbladderPackaging' phase.
#   At frame 38225, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID43:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1950, transitioned to 'CalotTriangleDissection' phase.
#   At frame 25025, transitioned to 'ClippingCutting' phase.
#   At frame 29975, transitioned to 'GallbladderDissection' phase.
#   At frame 45775, transitioned to 'GallbladderPackaging' phase.
#   At frame 47600, transitioned to 'CleaningCoagulation' phase.
#   At frame 55600, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID01:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 525, transitioned to 'CalotTriangleDissection' phase.
#   At frame 16825, transitioned to 'ClippingCutting' phase.
#   At frame 22175, transitioned to 'GallbladderDissection' phase.
#   At frame 36750, transitioned to 'GallbladderPackaging' phase.
#   At frame 39200, transitioned to 'CleaningCoagulation' phase.
#   At frame 41025, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID70:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 875, transitioned to 'CalotTriangleDissection' phase.
#   At frame 13400, transitioned to 'ClippingCutting' phase.
#   At frame 15900, transitioned to 'GallbladderDissection' phase.
#   At frame 25025, transitioned to 'CleaningCoagulation' phase.
#   At frame 27025, transitioned to 'GallbladderPackaging' phase.
#   At frame 29300, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID36:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 5900, transitioned to 'CalotTriangleDissection' phase.
#   At frame 26975, transitioned to 'ClippingCutting' phase.
#   At frame 29925, transitioned to 'GallbladderDissection' phase.
#   At frame 55275, transitioned to 'CleaningCoagulation' phase.
#   At frame 56975, transitioned to 'GallbladderPackaging' phase.
#   At frame 58750, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID66:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 625, transitioned to 'CalotTriangleDissection' phase.
#   At frame 16900, transitioned to 'ClippingCutting' phase.
#   At frame 20900, transitioned to 'GallbladderDissection' phase.
#   At frame 39075, transitioned to 'CleaningCoagulation' phase.
#   At frame 41225, transitioned to 'GallbladderPackaging' phase.
#   At frame 43300, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID27:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1975, transitioned to 'CalotTriangleDissection' phase.
#   At frame 22625, transitioned to 'ClippingCutting' phase.
#   At frame 30675, transitioned to 'GallbladderDissection' phase.
#   At frame 43775, transitioned to 'GallbladderPackaging' phase.
#   At frame 48025, transitioned to 'CleaningCoagulation' phase.
#   At frame 50750, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID50:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1675, transitioned to 'CalotTriangleDissection' phase.
#   At frame 15950, transitioned to 'ClippingCutting' phase.
#   At frame 16825, transitioned to 'GallbladderDissection' phase.
#   At frame 25125, transitioned to 'GallbladderPackaging' phase.
#   At frame 26650, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID15:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 3451, transitioned to 'CalotTriangleDissection' phase.
#   At frame 11201, transitioned to 'ClippingCutting' phase.
#   At frame 18801, transitioned to 'GallbladderDissection' phase.
#   At frame 44726, transitioned to 'GallbladderPackaging' phase.
#   At frame 47126, transitioned to 'CleaningCoagulation' phase.
#   At frame 49576, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID111:
#
#
# Phase Transitions in VID29:
#   At frame 0, transitioned to 'CalotTriangleDissection' phase.
#   At frame 12725, transitioned to 'ClippingCutting' phase.
#   At frame 17250, transitioned to 'GallbladderDissection' phase.
#   At frame 42925, transitioned to 'GallbladderPackaging' phase.
#   At frame 45975, transitioned to 'CleaningCoagulation' phase.
#   At frame 57575, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID42:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 4875, transitioned to 'CalotTriangleDissection' phase.
#   At frame 43450, transitioned to 'ClippingCutting' phase.
#   At frame 51900, transitioned to 'GallbladderDissection' phase.
#   At frame 86175, transitioned to 'GallbladderPackaging' phase.
#   At frame 87800, transitioned to 'CleaningCoagulation' phase.
#   At frame 91475, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID96:
#
#
# Phase Transitions in VID80:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1425, transitioned to 'CalotTriangleDissection' phase.
#   At frame 28400, transitioned to 'ClippingCutting' phase.
#   At frame 31700, transitioned to 'GallbladderDissection' phase.
#   At frame 38275, transitioned to 'GallbladderPackaging' phase.
#   At frame 39425, transitioned to 'CleaningCoagulation' phase.
#   At frame 39975, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID47:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 4525, transitioned to 'CalotTriangleDissection' phase.
#   At frame 18700, transitioned to 'ClippingCutting' phase.
#   At frame 22475, transitioned to 'GallbladderDissection' phase.
#   At frame 45775, transitioned to 'GallbladderPackaging' phase.
#   At frame 47425, transitioned to 'CleaningCoagulation' phase.
#   At frame 55425, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID49:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 2250, transitioned to 'CalotTriangleDissection' phase.
#   At frame 11725, transitioned to 'ClippingCutting' phase.
#   At frame 13300, transitioned to 'GallbladderDissection' phase.
#   At frame 27775, transitioned to 'GallbladderPackaging' phase.
#   At frame 29950, transitioned to 'CleaningCoagulation' phase.
#   At frame 39625, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID56:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 2625, transitioned to 'CalotTriangleDissection' phase.
#   At frame 24875, transitioned to 'ClippingCutting' phase.
#   At frame 26075, transitioned to 'GallbladderDissection' phase.
#   At frame 39075, transitioned to 'GallbladderPackaging' phase.
#   At frame 41975, transitioned to 'CleaningCoagulation' phase.
#   At frame 44575, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID10:
#   At frame 0, transitioned to 'CalotTriangleDissection' phase.
#   At frame 22775, transitioned to 'ClippingCutting' phase.
#   At frame 25750, transitioned to 'GallbladderDissection' phase.
#   At frame 30025, transitioned to 'GallbladderPackaging' phase.
#   At frame 37325, transitioned to 'CleaningCoagulation' phase.
#   At frame 38275, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID26:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 2450, transitioned to 'CalotTriangleDissection' phase.
#   At frame 18375, transitioned to 'ClippingCutting' phase.
#   At frame 22875, transitioned to 'GallbladderDissection' phase.
#   At frame 37575, transitioned to 'GallbladderPackaging' phase.
#   At frame 39100, transitioned to 'CleaningCoagulation' phase.
#   At frame 43800, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID06:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1375, transitioned to 'CalotTriangleDissection' phase.
#   At frame 30700, transitioned to 'ClippingCutting' phase.
#   At frame 35150, transitioned to 'GallbladderDissection' phase.
#   At frame 44175, transitioned to 'GallbladderPackaging' phase.
#   At frame 45900, transitioned to 'CleaningCoagulation' phase.
#   At frame 51625, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID13:
#   At frame 0, transitioned to 'CalotTriangleDissection' phase.
#   At frame 9200, transitioned to 'ClippingCutting' phase.
#   At frame 11250, transitioned to 'GallbladderDissection' phase.
#   At frame 20500, transitioned to 'GallbladderPackaging' phase.
#   At frame 22250, transitioned to 'CleaningCoagulation' phase.
#   At frame 22975, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID32:
#   At frame 0, transitioned to 'CalotTriangleDissection' phase.
#   At frame 25450, transitioned to 'ClippingCutting' phase.
#   At frame 28525, transitioned to 'GallbladderDissection' phase.
#   At frame 44975, transitioned to 'GallbladderPackaging' phase.
#   At frame 46850, transitioned to 'GallbladderRetraction' phase.
#   At frame 49375, transitioned to 'CleaningCoagulation' phase.
#
#
# Phase Transitions in VID51:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 5950, transitioned to 'CalotTriangleDissection' phase.
#   At frame 34175, transitioned to 'ClippingCutting' phase.
#   At frame 49975, transitioned to 'GallbladderDissection' phase.
#   At frame 65025, transitioned to 'GallbladderPackaging' phase.
#   At frame 67350, transitioned to 'CleaningCoagulation' phase.
#   At frame 72025, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID25:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1175, transitioned to 'CalotTriangleDissection' phase.
#   At frame 22950, transitioned to 'ClippingCutting' phase.
#   At frame 25950, transitioned to 'GallbladderDissection' phase.
#   At frame 39975, transitioned to 'GallbladderPackaging' phase.
#   At frame 42600, transitioned to 'CleaningCoagulation' phase.
#   At frame 51875, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID08:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 2450, transitioned to 'CalotTriangleDissection' phase.
#   At frame 19125, transitioned to 'ClippingCutting' phase.
#   At frame 21350, transitioned to 'GallbladderDissection' phase.
#   At frame 29100, transitioned to 'GallbladderPackaging' phase.
#   At frame 30800, transitioned to 'CleaningCoagulation' phase.
#   At frame 33275, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID12:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 3900, transitioned to 'CalotTriangleDissection' phase.
#   At frame 12950, transitioned to 'ClippingCutting' phase.
#   At frame 15250, transitioned to 'GallbladderDissection' phase.
#   At frame 22950, transitioned to 'GallbladderPackaging' phase.
#   At frame 24000, transitioned to 'GallbladderRetraction' phase.
#   At frame 24700, transitioned to 'CleaningCoagulation' phase.
#
#
# Phase Transitions in VID68:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 2550, transitioned to 'CalotTriangleDissection' phase.
#   At frame 23225, transitioned to 'ClippingCutting' phase.
#   At frame 27275, transitioned to 'GallbladderDissection' phase.
#   At frame 40600, transitioned to 'GallbladderPackaging' phase.
#   At frame 42325, transitioned to 'CleaningCoagulation' phase.
#   At frame 47200, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID52:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 2750, transitioned to 'CalotTriangleDissection' phase.
#   At frame 14600, transitioned to 'ClippingCutting' phase.
#   At frame 22775, transitioned to 'GallbladderDissection' phase.
#   At frame 32575, transitioned to 'GallbladderPackaging' phase.
#   At frame 34250, transitioned to 'CleaningCoagulation' phase.
#   At frame 48000, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID79:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1350, transitioned to 'CalotTriangleDissection' phase.
#   At frame 40450, transitioned to 'ClippingCutting' phase.
#   At frame 43800, transitioned to 'GallbladderDissection' phase.
#   At frame 70925, transitioned to 'CleaningCoagulation' phase.
#   At frame 78600, transitioned to 'GallbladderPackaging' phase.
#   At frame 81150, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID75:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 3050, transitioned to 'CalotTriangleDissection' phase.
#   At frame 12600, transitioned to 'ClippingCutting' phase.
#   At frame 14000, transitioned to 'GallbladderDissection' phase.
#   At frame 43800, transitioned to 'GallbladderPackaging' phase.
#   At frame 47250, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID62:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 500, transitioned to 'CalotTriangleDissection' phase.
#   At frame 27250, transitioned to 'ClippingCutting' phase.
#   At frame 29000, transitioned to 'GallbladderDissection' phase.
#   At frame 46500, transitioned to 'GallbladderPackaging' phase.
#   At frame 47850, transitioned to 'CleaningCoagulation' phase.
#   At frame 50275, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID18:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 825, transitioned to 'CalotTriangleDissection' phase.
#   At frame 19550, transitioned to 'ClippingCutting' phase.
#   At frame 25500, transitioned to 'GallbladderDissection' phase.
#   At frame 40825, transitioned to 'GallbladderPackaging' phase.
#   At frame 42750, transitioned to 'CleaningCoagulation' phase.
#   At frame 47100, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID22:
#   At frame 0, transitioned to 'CalotTriangleDissection' phase.
#   At frame 11475, transitioned to 'ClippingCutting' phase.
#   At frame 16075, transitioned to 'GallbladderDissection' phase.
#   At frame 26475, transitioned to 'GallbladderPackaging' phase.
#   At frame 28650, transitioned to 'CleaningCoagulation' phase.
#   At frame 35675, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID43_CLEAN:
#
#
# Phase Transitions in VID60_OLD:
#
#
# Phase Transitions in VID22_CLEAN:
#
#
# Phase Transitions in VID60_CLEAN:
#
#
# Phase Transitions in VID02_CLEAN:
#
#
# Phase Transitions in VID22_OLD:
#
#
# Phase Transitions in VID74_OLD:
#
#
# Phase Transitions in VID74_CLEAN:
#
#
# Phase Transitions in VID43_OLD:
#
#
# Phase Transitions in VID02_OLD:
#
#
# Phase Transitions in VID03:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 900, transitioned to 'CalotTriangleDissection' phase.
#   At frame 111125, transitioned to 'ClippingCutting' phase.
#   At frame 114375, transitioned to 'GallbladderDissection' phase.
#   At frame 127325, transitioned to 'GallbladderPackaging' phase.
#   At frame 129350, transitioned to 'CleaningCoagulation' phase.
#   At frame 143250, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID07:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1375, transitioned to 'CalotTriangleDissection' phase.
#   At frame 14600, transitioned to 'ClippingCutting' phase.
#   At frame 21925, transitioned to 'GallbladderDissection' phase.
#   At frame 100150, transitioned to 'GallbladderPackaging' phase.
#   At frame 103200, transitioned to 'CleaningCoagulation' phase.
#   At frame 111775, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID09:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 2475, transitioned to 'CalotTriangleDissection' phase.
#   At frame 26700, transitioned to 'ClippingCutting' phase.
#   At frame 31250, transitioned to 'GallbladderDissection' phase.
#   At frame 58550, transitioned to 'GallbladderPackaging' phase.
#   At frame 61250, transitioned to 'CleaningCoagulation' phase.
#   At frame 65550, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID11:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1075, transitioned to 'CalotTriangleDissection' phase.
#   At frame 50925, transitioned to 'ClippingCutting' phase.
#   At frame 59700, transitioned to 'GallbladderDissection' phase.
#   At frame 74025, transitioned to 'GallbladderPackaging' phase.
#   At frame 75850, transitioned to 'CleaningCoagulation' phase.
#   At frame 78650, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID41:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 7975, transitioned to 'CalotTriangleDissection' phase.
#   At frame 39150, transitioned to 'ClippingCutting' phase.
#   At frame 43450, transitioned to 'GallbladderDissection' phase.
#   At frame 66400, transitioned to 'CleaningCoagulation' phase.
#   At frame 69825, transitioned to 'GallbladderPackaging' phase.
#   At frame 74350, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID16:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1175, transitioned to 'CalotTriangleDissection' phase.
#   At frame 31225, transitioned to 'ClippingCutting' phase.
#   At frame 37900, transitioned to 'GallbladderDissection' phase.
#   At frame 65650, transitioned to 'GallbladderPackaging' phase.
#   At frame 68950, transitioned to 'CleaningCoagulation' phase.
#   At frame 71400, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID17:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 3475, transitioned to 'CalotTriangleDissection' phase.
#   At frame 14575, transitioned to 'ClippingCutting' phase.
#   At frame 17175, transitioned to 'GallbladderDissection' phase.
#   At frame 25675, transitioned to 'CleaningCoagulation' phase.
#   At frame 28675, transitioned to 'GallbladderPackaging' phase.
#   At frame 30525, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID19:
#   At frame 0, transitioned to 'CalotTriangleDissection' phase.
#   At frame 38725, transitioned to 'ClippingCutting' phase.
#   At frame 42600, transitioned to 'GallbladderDissection' phase.
#   At frame 54500, transitioned to 'GallbladderPackaging' phase.
#   At frame 57425, transitioned to 'CleaningCoagulation' phase.
#   At frame 59800, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID20:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 3125, transitioned to 'CalotTriangleDissection' phase.
#   At frame 15925, transitioned to 'ClippingCutting' phase.
#   At frame 18050, transitioned to 'GallbladderDissection' phase.
#   At frame 26525, transitioned to 'GallbladderPackaging' phase.
#   At frame 28650, transitioned to 'CleaningCoagulation' phase.
#   At frame 34875, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID44:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 3875, transitioned to 'CalotTriangleDissection' phase.
#   At frame 32100, transitioned to 'ClippingCutting' phase.
#   At frame 35925, transitioned to 'GallbladderDissection' phase.
#   At frame 70200, transitioned to 'GallbladderPackaging' phase.
#   At frame 72500, transitioned to 'CleaningCoagulation' phase.
#   At frame 76875, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID45:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 2025, transitioned to 'CalotTriangleDissection' phase.
#   At frame 23975, transitioned to 'ClippingCutting' phase.
#   At frame 25875, transitioned to 'GallbladderDissection' phase.
#   At frame 59150, transitioned to 'GallbladderPackaging' phase.
#   At frame 63025, transitioned to 'CleaningCoagulation' phase.
#   At frame 76875, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID46:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 2475, transitioned to 'CalotTriangleDissection' phase.
#   At frame 14600, transitioned to 'ClippingCutting' phase.
#   At frame 17425, transitioned to 'GallbladderDissection' phase.
#   At frame 32050, transitioned to 'GallbladderPackaging' phase.
#   At frame 34425, transitioned to 'CleaningCoagulation' phase.
#   At frame 39225, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID21:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 5350, transitioned to 'CalotTriangleDissection' phase.
#   At frame 16925, transitioned to 'ClippingCutting' phase.
#   At frame 23225, transitioned to 'GallbladderDissection' phase.
#   At frame 29150, transitioned to 'GallbladderPackaging' phase.
#   At frame 30325, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID24:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 10600, transitioned to 'CalotTriangleDissection' phase.
#   At frame 18075, transitioned to 'ClippingCutting' phase.
#   At frame 20825, transitioned to 'GallbladderDissection' phase.
#   At frame 40025, transitioned to 'GallbladderPackaging' phase.
#   At frame 42300, transitioned to 'CleaningCoagulation' phase.
#   At frame 48375, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID28:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1050, transitioned to 'CalotTriangleDissection' phase.
#   At frame 17675, transitioned to 'ClippingCutting' phase.
#   At frame 20425, transitioned to 'GallbladderDissection' phase.
#   At frame 25425, transitioned to 'GallbladderPackaging' phase.
#   At frame 27375, transitioned to 'CleaningCoagulation' phase.
#   At frame 29200, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID30:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 3000, transitioned to 'CalotTriangleDissection' phase.
#   At frame 20775, transitioned to 'ClippingCutting' phase.
#   At frame 31400, transitioned to 'GallbladderDissection' phase.
#   At frame 55750, transitioned to 'GallbladderPackaging' phase.
#   At frame 57900, transitioned to 'CleaningCoagulation' phase.
#   At frame 71650, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID33:
#   At frame 0, transitioned to 'CalotTriangleDissection' phase.
#   At frame 8275, transitioned to 'ClippingCutting' phase.
#   At frame 10850, transitioned to 'GallbladderDissection' phase.
#   At frame 25300, transitioned to 'GallbladderPackaging' phase.
#   At frame 27225, transitioned to 'CleaningCoagulation' phase.
#   At frame 31050, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID34:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 750, transitioned to 'CalotTriangleDissection' phase.
#   At frame 9650, transitioned to 'ClippingCutting' phase.
#   At frame 12000, transitioned to 'GallbladderDissection' phase.
#   At frame 27175, transitioned to 'GallbladderPackaging' phase.
#   At frame 29275, transitioned to 'CleaningCoagulation' phase.
#   At frame 31475, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID37:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 876, transitioned to 'CalotTriangleDissection' phase.
#   At frame 16351, transitioned to 'ClippingCutting' phase.
#   At frame 19076, transitioned to 'GallbladderDissection' phase.
#   At frame 27476, transitioned to 'CleaningCoagulation' phase.
#   At frame 28976, transitioned to 'GallbladderPackaging' phase.
#   At frame 30451, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID38:
#   At frame 0, transitioned to 'CalotTriangleDissection' phase.
#   At frame 49550, transitioned to 'ClippingCutting' phase.
#   At frame 53900, transitioned to 'GallbladderDissection' phase.
#   At frame 60775, transitioned to 'GallbladderPackaging' phase.
#   At frame 63225, transitioned to 'CleaningCoagulation' phase.
#   At frame 75825, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID53:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1675, transitioned to 'CalotTriangleDissection' phase.
#   At frame 29075, transitioned to 'ClippingCutting' phase.
#   At frame 31200, transitioned to 'GallbladderDissection' phase.
#   At frame 64525, transitioned to 'GallbladderPackaging' phase.
#   At frame 66075, transitioned to 'CleaningCoagulation' phase.
#   At frame 80950, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID54:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 3125, transitioned to 'CalotTriangleDissection' phase.
#   At frame 32800, transitioned to 'ClippingCutting' phase.
#   At frame 37675, transitioned to 'GallbladderDissection' phase.
#   At frame 60450, transitioned to 'GallbladderPackaging' phase.
#   At frame 62275, transitioned to 'CleaningCoagulation' phase.
#   At frame 74700, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID39:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 925, transitioned to 'CalotTriangleDissection' phase.
#   At frame 20725, transitioned to 'ClippingCutting' phase.
#   At frame 24675, transitioned to 'GallbladderDissection' phase.
#   At frame 35850, transitioned to 'GallbladderPackaging' phase.
#   At frame 37650, transitioned to 'CleaningCoagulation' phase.
#   At frame 40125, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID55:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 525, transitioned to 'CalotTriangleDissection' phase.
#   At frame 12050, transitioned to 'ClippingCutting' phase.
#   At frame 14025, transitioned to 'GallbladderDissection' phase.
#   At frame 22200, transitioned to 'GallbladderPackaging' phase.
#   At frame 23550, transitioned to 'CleaningCoagulation' phase.
#   At frame 24700, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID58:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 2000, transitioned to 'CalotTriangleDissection' phase.
#   At frame 86675, transitioned to 'ClippingCutting' phase.
#   At frame 103525, transitioned to 'GallbladderDissection' phase.
#   At frame 136675, transitioned to 'GallbladderPackaging' phase.
#   At frame 138150, transitioned to 'CleaningCoagulation' phase.
#   At frame 144925, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID59:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 875, transitioned to 'CalotTriangleDissection' phase.
#   At frame 12225, transitioned to 'ClippingCutting' phase.
#   At frame 14225, transitioned to 'GallbladderDissection' phase.
#   At frame 21525, transitioned to 'GallbladderPackaging' phase.
#   At frame 23175, transitioned to 'CleaningCoagulation' phase.
#   At frame 24575, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID61:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 11199, transitioned to 'CalotTriangleDissection' phase.
#   At frame 35325, transitioned to 'ClippingCutting' phase.
#   At frame 40100, transitioned to 'GallbladderDissection' phase.
#   At frame 104050, transitioned to 'GallbladderPackaging' phase.
#   At frame 106075, transitioned to 'CleaningCoagulation' phase.
#   At frame 107825, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID63:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 3000, transitioned to 'CalotTriangleDissection' phase.
#   At frame 17725, transitioned to 'ClippingCutting' phase.
#   At frame 18850, transitioned to 'GallbladderDissection' phase.
#   At frame 75975, transitioned to 'GallbladderPackaging' phase.
#   At frame 82175, transitioned to 'CleaningCoagulation' phase.
#   At frame 84825, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID64:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1525, transitioned to 'CalotTriangleDissection' phase.
#   At frame 27925, transitioned to 'ClippingCutting' phase.
#   At frame 30500, transitioned to 'GallbladderDissection' phase.
#   At frame 49600, transitioned to 'CleaningCoagulation' phase.
#   At frame 54075, transitioned to 'GallbladderPackaging' phase.
#   At frame 56625, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID67:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 4825, transitioned to 'CalotTriangleDissection' phase.
#   At frame 26100, transitioned to 'ClippingCutting' phase.
#   At frame 28825, transitioned to 'GallbladderDissection' phase.
#   At frame 53575, transitioned to 'GallbladderPackaging' phase.
#   At frame 55550, transitioned to 'CleaningCoagulation' phase.
#   At frame 56625, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID69:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1725, transitioned to 'CalotTriangleDissection' phase.
#   At frame 44000, transitioned to 'ClippingCutting' phase.
#   At frame 56800, transitioned to 'GallbladderDissection' phase.
#   At frame 106425, transitioned to 'GallbladderPackaging' phase.
#   At frame 111500, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID71:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 900, transitioned to 'CalotTriangleDissection' phase.
#   At frame 31025, transitioned to 'ClippingCutting' phase.
#   At frame 32550, transitioned to 'GallbladderDissection' phase.
#   At frame 55225, transitioned to 'GallbladderPackaging' phase.
#   At frame 62300, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID72:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 3425, transitioned to 'CalotTriangleDissection' phase.
#   At frame 32950, transitioned to 'ClippingCutting' phase.
#   At frame 35775, transitioned to 'GallbladderDissection' phase.
#   At frame 65725, transitioned to 'GallbladderPackaging' phase.
#   At frame 67675, transitioned to 'CleaningCoagulation' phase.
#   At frame 74950, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID76:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 750, transitioned to 'CalotTriangleDissection' phase.
#   At frame 23850, transitioned to 'ClippingCutting' phase.
#   At frame 35325, transitioned to 'GallbladderDissection' phase.
#   At frame 60600, transitioned to 'GallbladderPackaging' phase.
#   At frame 62325, transitioned to 'CleaningCoagulation' phase.
#   At frame 64725, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in VID77:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 4400, transitioned to 'CalotTriangleDissection' phase.
#   At frame 21725, transitioned to 'ClippingCutting' phase.
#   At frame 25200, transitioned to 'GallbladderDissection' phase.
#   At frame 48175, transitioned to 'GallbladderPackaging' phase.
#   At frame 50000, transitioned to 'CleaningCoagulation' phase.
#   At frame 60975, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video01:
#
#
# Phase Transitions in video02:
#
#
# Phase Transitions in video03:
#
#
# Phase Transitions in video04:
#
#
# Phase Transitions in video05:
#
#
# Phase Transitions in video06:
#
#
# Phase Transitions in video07:
#
#
# Phase Transitions in video08:
#
#
# Phase Transitions in video09:
#
#
# Phase Transitions in video10:
#
#
# Phase Transitions in video11:
#
#
# Phase Transitions in video12:
#
#
# Phase Transitions in video13:
#
#
# Phase Transitions in video14:
#
#
# Phase Transitions in video15:
#
#
# Phase Transitions in video16:
#
#
# Phase Transitions in video17:
#
#
# Phase Transitions in video18:
#
#
# Phase Transitions in video19:
#
#
# Phase Transitions in video20:
#
#
# Phase Transitions in video21:
#
#
# Phase Transitions in video22:
#
#
# Phase Transitions in video23:
#
#
# Phase Transitions in video24:
#
#
# Phase Transitions in video25:
#
#
# Phase Transitions in video26:
#
#
# Phase Transitions in video27:
#
#
# Phase Transitions in video28:
#
#
# Phase Transitions in video29:
#
#
# Phase Transitions in video30:
#
#
# Phase Transitions in video31:
#
#
# Phase Transitions in video32:
#
#
# Phase Transitions in video33:
#
#
# Phase Transitions in video34:
#
#
# Phase Transitions in video35:
#
#
# Phase Transitions in video36:
#
#
# Phase Transitions in video37:
#
#
# Phase Transitions in video38:
#
#
# Phase Transitions in video39:
#
#
# Phase Transitions in video40:
#
#
# Phase Transitions in video41:
#
#
# Phase Transitions in video42:
#
#
# Phase Transitions in video43:
#
#
# Phase Transitions in video44:
#
#
# Phase Transitions in video45:
#
#
# Phase Transitions in video46:
#
#
# Phase Transitions in video47:
#
#
# Phase Transitions in video48:
#
#
# Phase Transitions in video49:
#
#
# Phase Transitions in video50:
#
#
# Phase Transitions in video51:
#
#
# Phase Transitions in video52:
#
#
# Phase Transitions in video53:
#
#
# Phase Transitions in video54:
#
#
# Phase Transitions in video55:
#
#
# Phase Transitions in video56:
#
#
# Phase Transitions in video57:
#
#
# Phase Transitions in video58:
#
#
# Phase Transitions in video59:
#
#
# Phase Transitions in video60:
#
#
# Phase Transitions in video61:
#
#
# Phase Transitions in video62:
#
#
# Phase Transitions in video63:
#
#
# Phase Transitions in video64:
#
#
# Phase Transitions in video65:
#
#
# Phase Transitions in video66:
#
#
# Phase Transitions in video67:
#
#
# Phase Transitions in video68:
#
#
# Phase Transitions in video69:
#
#
# Phase Transitions in video70:
#
#
# Phase Transitions in video71:
#
#
# Phase Transitions in video72:
#
#
# Phase Transitions in video73:
#
#
# Phase Transitions in video74:
#
#
# Phase Transitions in video75:
#
#
# Phase Transitions in video76:
#
#
# Phase Transitions in video77:
#
#
# Phase Transitions in video78:
#
#
# Phase Transitions in video79:
#
#
# Phase Transitions in video80:
#
#
# Phase Transitions in video01-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 525, transitioned to 'CalotTriangleDissection' phase.
#   At frame 16825, transitioned to 'ClippingCutting' phase.
#   At frame 22175, transitioned to 'GallbladderDissection' phase.
#   At frame 36750, transitioned to 'GallbladderPackaging' phase.
#   At frame 39200, transitioned to 'CleaningCoagulation' phase.
#   At frame 41025, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video02-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 12025, transitioned to 'CalotTriangleDissection' phase.
#   At frame 31325, transitioned to 'ClippingCutting' phase.
#   At frame 39525, transitioned to 'GallbladderDissection' phase.
#   At frame 63425, transitioned to 'GallbladderPackaging' phase.
#   At frame 64950, transitioned to 'CleaningCoagulation' phase.
#   At frame 69475, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video03-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 900, transitioned to 'CalotTriangleDissection' phase.
#   At frame 111125, transitioned to 'ClippingCutting' phase.
#   At frame 114375, transitioned to 'GallbladderDissection' phase.
#   At frame 127325, transitioned to 'GallbladderPackaging' phase.
#   At frame 129350, transitioned to 'CleaningCoagulation' phase.
#   At frame 143250, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video04-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 7275, transitioned to 'CalotTriangleDissection' phase.
#   At frame 22450, transitioned to 'ClippingCutting' phase.
#   At frame 24100, transitioned to 'GallbladderDissection' phase.
#   At frame 31000, transitioned to 'GallbladderPackaging' phase.
#   At frame 31950, transitioned to 'CleaningCoagulation' phase.
#   At frame 34325, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video05-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1600, transitioned to 'CalotTriangleDissection' phase.
#   At frame 25375, transitioned to 'ClippingCutting' phase.
#   At frame 32600, transitioned to 'GallbladderDissection' phase.
#   At frame 38600, transitioned to 'GallbladderPackaging' phase.
#   At frame 41575, transitioned to 'CleaningCoagulation' phase.
#   At frame 44350, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video06-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1375, transitioned to 'CalotTriangleDissection' phase.
#   At frame 30700, transitioned to 'ClippingCutting' phase.
#   At frame 35150, transitioned to 'GallbladderDissection' phase.
#   At frame 44175, transitioned to 'GallbladderPackaging' phase.
#   At frame 45900, transitioned to 'CleaningCoagulation' phase.
#   At frame 51625, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video07-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1375, transitioned to 'CalotTriangleDissection' phase.
#   At frame 14600, transitioned to 'ClippingCutting' phase.
#   At frame 21925, transitioned to 'GallbladderDissection' phase.
#   At frame 100150, transitioned to 'GallbladderPackaging' phase.
#   At frame 103200, transitioned to 'CleaningCoagulation' phase.
#   At frame 111775, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video08-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 2450, transitioned to 'CalotTriangleDissection' phase.
#   At frame 19125, transitioned to 'ClippingCutting' phase.
#   At frame 21350, transitioned to 'GallbladderDissection' phase.
#   At frame 29100, transitioned to 'GallbladderPackaging' phase.
#   At frame 30800, transitioned to 'CleaningCoagulation' phase.
#   At frame 33275, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video09-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 2475, transitioned to 'CalotTriangleDissection' phase.
#   At frame 26700, transitioned to 'ClippingCutting' phase.
#   At frame 31250, transitioned to 'GallbladderDissection' phase.
#   At frame 58550, transitioned to 'GallbladderPackaging' phase.
#   At frame 61250, transitioned to 'CleaningCoagulation' phase.
#   At frame 65550, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video10-phase:
#   At frame 0, transitioned to 'CalotTriangleDissection' phase.
#   At frame 22775, transitioned to 'ClippingCutting' phase.
#   At frame 25750, transitioned to 'GallbladderDissection' phase.
#   At frame 30025, transitioned to 'GallbladderPackaging' phase.
#   At frame 37325, transitioned to 'CleaningCoagulation' phase.
#   At frame 38275, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video11-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1075, transitioned to 'CalotTriangleDissection' phase.
#   At frame 50925, transitioned to 'ClippingCutting' phase.
#   At frame 59700, transitioned to 'GallbladderDissection' phase.
#   At frame 74025, transitioned to 'GallbladderPackaging' phase.
#   At frame 75850, transitioned to 'CleaningCoagulation' phase.
#   At frame 78650, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video41-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 7975, transitioned to 'CalotTriangleDissection' phase.
#   At frame 39150, transitioned to 'ClippingCutting' phase.
#   At frame 43450, transitioned to 'GallbladderDissection' phase.
#   At frame 66400, transitioned to 'CleaningCoagulation' phase.
#   At frame 69825, transitioned to 'GallbladderPackaging' phase.
#   At frame 74350, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video12-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 3900, transitioned to 'CalotTriangleDissection' phase.
#   At frame 12950, transitioned to 'ClippingCutting' phase.
#   At frame 15250, transitioned to 'GallbladderDissection' phase.
#   At frame 22950, transitioned to 'GallbladderPackaging' phase.
#   At frame 24000, transitioned to 'GallbladderRetraction' phase.
#   At frame 24700, transitioned to 'CleaningCoagulation' phase.
#
#
# Phase Transitions in video13-phase:
#   At frame 0, transitioned to 'CalotTriangleDissection' phase.
#   At frame 9200, transitioned to 'ClippingCutting' phase.
#   At frame 11250, transitioned to 'GallbladderDissection' phase.
#   At frame 20500, transitioned to 'GallbladderPackaging' phase.
#   At frame 22250, transitioned to 'CleaningCoagulation' phase.
# ...
#   At frame 36600, transitioned to 'GallbladderDissection' phase.
#   At frame 44775, transitioned to 'GallbladderPackaging' phase.
#   At frame 46475, transitioned to 'CleaningCoagulation' phase.
#   At frame 51550, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video36-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 5900, transitioned to 'CalotTriangleDissection' phase.
#   At frame 26975, transitioned to 'ClippingCutting' phase.
#   At frame 29925, transitioned to 'GallbladderDissection' phase.
#   At frame 55275, transitioned to 'CleaningCoagulation' phase.
#   At frame 56975, transitioned to 'GallbladderPackaging' phase.
#   At frame 58750, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video37-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 876, transitioned to 'CalotTriangleDissection' phase.
#   At frame 16351, transitioned to 'ClippingCutting' phase.
#   At frame 19076, transitioned to 'GallbladderDissection' phase.
#   At frame 27476, transitioned to 'CleaningCoagulation' phase.
#   At frame 28976, transitioned to 'GallbladderPackaging' phase.
#   At frame 30451, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video52-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 2750, transitioned to 'CalotTriangleDissection' phase.
#   At frame 14600, transitioned to 'ClippingCutting' phase.
#   At frame 22775, transitioned to 'GallbladderDissection' phase.
#   At frame 32575, transitioned to 'GallbladderPackaging' phase.
#   At frame 34250, transitioned to 'CleaningCoagulation' phase.
#   At frame 48000, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video38-phase:
#   At frame 0, transitioned to 'CalotTriangleDissection' phase.
#   At frame 49550, transitioned to 'ClippingCutting' phase.
#   At frame 53900, transitioned to 'GallbladderDissection' phase.
#   At frame 60775, transitioned to 'GallbladderPackaging' phase.
#   At frame 63225, transitioned to 'CleaningCoagulation' phase.
#   At frame 75825, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video53-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1675, transitioned to 'CalotTriangleDissection' phase.
#   At frame 29075, transitioned to 'ClippingCutting' phase.
#   At frame 31200, transitioned to 'GallbladderDissection' phase.
#   At frame 64525, transitioned to 'GallbladderPackaging' phase.
#   At frame 66075, transitioned to 'CleaningCoagulation' phase.
#   At frame 80950, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video54-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 3125, transitioned to 'CalotTriangleDissection' phase.
#   At frame 32800, transitioned to 'ClippingCutting' phase.
#   At frame 37675, transitioned to 'GallbladderDissection' phase.
#   At frame 60450, transitioned to 'GallbladderPackaging' phase.
#   At frame 62275, transitioned to 'CleaningCoagulation' phase.
#   At frame 74700, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video39-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 925, transitioned to 'CalotTriangleDissection' phase.
#   At frame 20725, transitioned to 'ClippingCutting' phase.
#   At frame 24675, transitioned to 'GallbladderDissection' phase.
#   At frame 35850, transitioned to 'GallbladderPackaging' phase.
#   At frame 37650, transitioned to 'CleaningCoagulation' phase.
#   At frame 40125, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video55-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 525, transitioned to 'CalotTriangleDissection' phase.
#   At frame 12050, transitioned to 'ClippingCutting' phase.
#   At frame 14025, transitioned to 'GallbladderDissection' phase.
#   At frame 22200, transitioned to 'GallbladderPackaging' phase.
#   At frame 23550, transitioned to 'CleaningCoagulation' phase.
#   At frame 24700, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video56-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 2625, transitioned to 'CalotTriangleDissection' phase.
#   At frame 24875, transitioned to 'ClippingCutting' phase.
#   At frame 26075, transitioned to 'GallbladderDissection' phase.
#   At frame 39075, transitioned to 'GallbladderPackaging' phase.
#   At frame 41975, transitioned to 'CleaningCoagulation' phase.
#   At frame 44575, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video57-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 3625, transitioned to 'CalotTriangleDissection' phase.
#   At frame 28125, transitioned to 'ClippingCutting' phase.
#   At frame 33050, transitioned to 'GallbladderDissection' phase.
#   At frame 56175, transitioned to 'CleaningCoagulation' phase.
#   At frame 59750, transitioned to 'GallbladderPackaging' phase.
#   At frame 61775, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video40-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 6550, transitioned to 'CalotTriangleDissection' phase.
#   At frame 33425, transitioned to 'ClippingCutting' phase.
#   At frame 37950, transitioned to 'GallbladderDissection' phase.
#   At frame 50175, transitioned to 'GallbladderPackaging' phase.
#   At frame 52750, transitioned to 'CleaningCoagulation' phase.
#   At frame 54450, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video58-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 2000, transitioned to 'CalotTriangleDissection' phase.
#   At frame 86675, transitioned to 'ClippingCutting' phase.
#   At frame 103525, transitioned to 'GallbladderDissection' phase.
#   At frame 136675, transitioned to 'GallbladderPackaging' phase.
#   At frame 138150, transitioned to 'CleaningCoagulation' phase.
#   At frame 144925, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video59-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 875, transitioned to 'CalotTriangleDissection' phase.
#   At frame 12225, transitioned to 'ClippingCutting' phase.
#   At frame 14225, transitioned to 'GallbladderDissection' phase.
#   At frame 21525, transitioned to 'GallbladderPackaging' phase.
#   At frame 23175, transitioned to 'CleaningCoagulation' phase.
#   At frame 24575, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video60-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 8075, transitioned to 'CalotTriangleDissection' phase.
#   At frame 52525, transitioned to 'ClippingCutting' phase.
#   At frame 54625, transitioned to 'GallbladderDissection' phase.
#   At frame 57275, transitioned to 'CleaningCoagulation' phase.
#   At frame 59625, transitioned to 'GallbladderPackaging' phase.
#   At frame 62325, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video61-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 11199, transitioned to 'CalotTriangleDissection' phase.
#   At frame 35325, transitioned to 'ClippingCutting' phase.
#   At frame 40100, transitioned to 'GallbladderDissection' phase.
#   At frame 104050, transitioned to 'GallbladderPackaging' phase.
#   At frame 106075, transitioned to 'CleaningCoagulation' phase.
#   At frame 107825, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video62-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 500, transitioned to 'CalotTriangleDissection' phase.
#   At frame 27250, transitioned to 'ClippingCutting' phase.
#   At frame 29000, transitioned to 'GallbladderDissection' phase.
#   At frame 46500, transitioned to 'GallbladderPackaging' phase.
#   At frame 47850, transitioned to 'CleaningCoagulation' phase.
#   At frame 50275, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video63-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 3000, transitioned to 'CalotTriangleDissection' phase.
#   At frame 17725, transitioned to 'ClippingCutting' phase.
#   At frame 18850, transitioned to 'GallbladderDissection' phase.
#   At frame 75975, transitioned to 'GallbladderPackaging' phase.
#   At frame 82175, transitioned to 'CleaningCoagulation' phase.
#   At frame 84825, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video64-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1525, transitioned to 'CalotTriangleDissection' phase.
#   At frame 27925, transitioned to 'ClippingCutting' phase.
#   At frame 30500, transitioned to 'GallbladderDissection' phase.
#   At frame 49600, transitioned to 'CleaningCoagulation' phase.
#   At frame 54075, transitioned to 'GallbladderPackaging' phase.
#   At frame 56625, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video65-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 6225, transitioned to 'CalotTriangleDissection' phase.
#   At frame 28600, transitioned to 'ClippingCutting' phase.
#   At frame 31300, transitioned to 'GallbladderDissection' phase.
#   At frame 43950, transitioned to 'GallbladderPackaging' phase.
#   At frame 45900, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video66-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 625, transitioned to 'CalotTriangleDissection' phase.
#   At frame 16900, transitioned to 'ClippingCutting' phase.
#   At frame 20900, transitioned to 'GallbladderDissection' phase.
#   At frame 39075, transitioned to 'CleaningCoagulation' phase.
#   At frame 41225, transitioned to 'GallbladderPackaging' phase.
#   At frame 43300, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video67-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 4825, transitioned to 'CalotTriangleDissection' phase.
#   At frame 26100, transitioned to 'ClippingCutting' phase.
#   At frame 28825, transitioned to 'GallbladderDissection' phase.
#   At frame 53575, transitioned to 'GallbladderPackaging' phase.
#   At frame 55550, transitioned to 'CleaningCoagulation' phase.
#   At frame 56625, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video68-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 2550, transitioned to 'CalotTriangleDissection' phase.
#   At frame 23225, transitioned to 'ClippingCutting' phase.
#   At frame 27275, transitioned to 'GallbladderDissection' phase.
#   At frame 40600, transitioned to 'GallbladderPackaging' phase.
#   At frame 42325, transitioned to 'CleaningCoagulation' phase.
#   At frame 47200, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video69-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1725, transitioned to 'CalotTriangleDissection' phase.
#   At frame 44000, transitioned to 'ClippingCutting' phase.
#   At frame 56800, transitioned to 'GallbladderDissection' phase.
#   At frame 106425, transitioned to 'GallbladderPackaging' phase.
#   At frame 111500, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video70-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 875, transitioned to 'CalotTriangleDissection' phase.
#   At frame 13400, transitioned to 'ClippingCutting' phase.
#   At frame 15900, transitioned to 'GallbladderDissection' phase.
#   At frame 25025, transitioned to 'CleaningCoagulation' phase.
#   At frame 27025, transitioned to 'GallbladderPackaging' phase.
#   At frame 29300, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video71-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 900, transitioned to 'CalotTriangleDissection' phase.
#   At frame 31025, transitioned to 'ClippingCutting' phase.
#   At frame 32550, transitioned to 'GallbladderDissection' phase.
#   At frame 55225, transitioned to 'GallbladderPackaging' phase.
#   At frame 62300, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video72-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 3425, transitioned to 'CalotTriangleDissection' phase.
#   At frame 32950, transitioned to 'ClippingCutting' phase.
#   At frame 35775, transitioned to 'GallbladderDissection' phase.
#   At frame 65725, transitioned to 'GallbladderPackaging' phase.
#   At frame 67675, transitioned to 'CleaningCoagulation' phase.
#   At frame 74950, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video73-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 2425, transitioned to 'CalotTriangleDissection' phase.
#   At frame 18175, transitioned to 'ClippingCutting' phase.
#   At frame 20775, transitioned to 'GallbladderDissection' phase.
#   At frame 27950, transitioned to 'GallbladderPackaging' phase.
#   At frame 29125, transitioned to 'CleaningCoagulation' phase.
#   At frame 32100, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video74-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 2175, transitioned to 'CalotTriangleDissection' phase.
#   At frame 12525, transitioned to 'ClippingCutting' phase.
#   At frame 15750, transitioned to 'GallbladderDissection' phase.
#   At frame 33425, transitioned to 'CleaningCoagulation' phase.
#   At frame 35675, transitioned to 'GallbladderPackaging' phase.
#   At frame 38225, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video75-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 3050, transitioned to 'CalotTriangleDissection' phase.
#   At frame 12600, transitioned to 'ClippingCutting' phase.
#   At frame 14000, transitioned to 'GallbladderDissection' phase.
#   At frame 43800, transitioned to 'GallbladderPackaging' phase.
#   At frame 47250, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video76-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 750, transitioned to 'CalotTriangleDissection' phase.
#   At frame 23850, transitioned to 'ClippingCutting' phase.
#   At frame 35325, transitioned to 'GallbladderDissection' phase.
#   At frame 60600, transitioned to 'GallbladderPackaging' phase.
#   At frame 62325, transitioned to 'CleaningCoagulation' phase.
#   At frame 64725, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video77-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 4400, transitioned to 'CalotTriangleDissection' phase.
#   At frame 21725, transitioned to 'ClippingCutting' phase.
#   At frame 25200, transitioned to 'GallbladderDissection' phase.
#   At frame 48175, transitioned to 'GallbladderPackaging' phase.
#   At frame 50000, transitioned to 'CleaningCoagulation' phase.
#   At frame 60975, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video78-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1100, transitioned to 'CalotTriangleDissection' phase.
#   At frame 8300, transitioned to 'ClippingCutting' phase.
#   At frame 9900, transitioned to 'GallbladderDissection' phase.
#   At frame 13950, transitioned to 'CleaningCoagulation' phase.
#   At frame 15775, transitioned to 'GallbladderPackaging' phase.
#   At frame 17350, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video79-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1350, transitioned to 'CalotTriangleDissection' phase.
#   At frame 40450, transitioned to 'ClippingCutting' phase.
#   At frame 43800, transitioned to 'GallbladderDissection' phase.
#   At frame 70925, transitioned to 'CleaningCoagulation' phase.
#   At frame 78600, transitioned to 'GallbladderPackaging' phase.
#   At frame 81150, transitioned to 'GallbladderRetraction' phase.
#
#
# Phase Transitions in video80-phase:
#   At frame 0, transitioned to 'Preparation' phase.
#   At frame 1425, transitioned to 'CalotTriangleDissection' phase.
#   At frame 28400, transitioned to 'ClippingCutting' phase.
#   At frame 31700, transitioned to 'GallbladderDissection' phase.
#   At frame 38275, transitioned to 'GallbladderPackaging' phase.
#   At frame 39425, transitioned to 'CleaningCoagulation' phase.
#   At frame 39975, transitioned to 'GallbladderRetraction' phase.

# %%
def extract_actions_for_phase(unified_data, video_id, phase):
    actions = []

    annotations = unified_data[video_id]["annotations"]
    for frame_id, data in annotations.items():
        if data.get("phase") == phase:
            categories = data.get("categories", {})
            for i in range(len(categories.get("instruments", []))):
                action = (
                    categories["instruments"][i],
                    categories["verbs"][i],
                    categories["targets"][i]
                )
                actions.append(action)
    
    return set(actions)  # Using a set to eliminate duplicates

# Example usage
preparation_actions = extract_actions_for_phase(unified_data, "VID01", "Preparation")
print("Actions during the Preparation phase in VID01:")
for action in preparation_actions:
    print(action)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 19
#      16     return set(actions)  # Using a set to eliminate duplicates
#      18 # Example usage
# ---> 19 preparation_actions = extract_actions_for_phase(unified_data, "VID01", "Preparation")
#      20 print("Actions during the Preparation phase in VID01:")
#      21 for action in preparation_actions:
#
# Cell In[32], line 12, in extract_actions_for_phase(unified_data, video_id, phase)
#       7         categories = data.get("categories", {})
#       8         for i in range(len(categories.get("instruments", []))):
#       9             action = (
#      10                 categories["instruments"][i],
#      11                 categories["verbs"][i],
# ---> 12                 categories["targets"][i]
#      13             )
#      14             actions.append(action)
#      16 return set(actions)
#
# IndexError: list index out of range

# %%
def get_frame_annotations(unified_data, video_id, frame_id):
    video_data = unified_data.get(video_id, {})
    return video_data.get("annotations", {}).get(frame_id, {})

# Example usage
frame_annotations = get_frame_annotations(unified_data, "VID01", "1")
print(f"Annotations for VID01, frame 1: {frame_annotations}")
# Out:
# Annotations for VID01, frame 1: {'categories': {'instruments': ['grasper'], 'verbs': ['grasp'], 'targets': ['gallbladder']}, 'qa': [{'question': 'Which anatomical structures are present?', 'answers': ['abdominal_wall_cavity, liver, gut, omentum, gallbladder']}, {'question': 'Which tools are present?', 'answers': ['grasper']}, {'question': 'What is the grasper doing?', 'answers': ['grasp']}, {'question': 'Which tool is operating on gallbladder?', 'answers': ['grasper']}, {'question': 'What anatomy is at the top-left of the frame ?', 'answers': ['abdominal_wall_cavity', '[67.0, 85.5]']}, {'question': 'What anatomy is at the top-mid of the frame ?', 'answers': ['liver', '[212.0, 119.5]']}, {'question': 'What number of objects are both below the red top-left object and above the top-mid liver object?', 'answers': ['0', 'single_and.json', 'count', 'NA']}, {'question': 'How many anatomys are both right of the abdominal_wall_cavity thing and to the left of the top-mid liver thing?', 'answers': ['1', 'single_and.json', 'count', 'NA']}, {'question': 'How many things are both right of the abdominal_wall_cavity thing and on the left side of the top-mid liver object?', 'answers': ['2', 'single_and.json', 'count', 'NA']}, {'question': 'What number of red anatomys are both to the right of the abdominal_wall_cavity object and left of the top-mid liver thing?', 'answers': ['0', 'single_and.json', 'count', 'NA']}, {'question': 'What name is the thing that is within the silver top-mid thing and to the right of the white anatomy?', 'answers': ['liver', 'single_and.json', 'query_component', 'NA']}, {'question': 'What is the name of the anatomy that is both to the right of the abdominal_wall_cavity thing and to the left of the yellow thing?', 'answers': ['gallbladder', 'single_and.json', 'query_component', 'NA']}, {'question': 'What is the name of the anatomy that is both right of the red top-left abdominal_wall_cavity anatomy and to the left of the yellow object?', 'answers': ['gallbladder', 'single_and.json', 'query_component', 'NA']}, {'question': 'There is a object that is below the grasper instrument and above the yellow thing?; what is its name?', 'answers': ['abdominal_wall_cavity', 'single_and.json', 'query_component', 'NA']}, {'question': 'What is the color of the thing that is both below the top-left abdominal_wall_cavity anatomy and on the left side of the gut thing?', 'answers': ['yellow', 'single_and.json', 'query_color', 'NA']}, {'question': 'There is a object that is both within the silver top-mid grasper instrument and within the gut object?; what is its color?', 'answers': ['brown', 'single_and.json', 'query_color', 'NA']}, {'question': 'What is the color of the anatomy that is both within the silver top-mid grasper instrument and within the gut object?', 'answers': ['brown', 'single_and.json', 'query_color', 'NA']}, {'question': 'There is a anatomy that is both below the top-left object and within the gut thing?; what is its color?', 'answers': ['yellow', 'single_and.json', 'query_color', 'NA']}, {'question': 'What number of silver grasper things are there?', 'answers': ['1', 'zero_hop.json', 'count', 'NA']}, {'question': 'How many brown bottom-left specimenbag anatomys are there?', 'answers': ['0', 'zero_hop.json', 'count', 'NA']}, {'question': 'What number of brown anatomys are there?', 'answers': ['1', 'zero_hop.json', 'count', 'NA']}, {'question': 'There is a liver thing; how many abdominal_wall_cavity anatomys are grasped by it?', 'answers': ['0', 'one_hop.json', 'count', 'relate_actional']}, {'question': 'What number of gut anatomys are below the liver object?', 'answers': ['1', 'one_hop.json', 'count', 'relate_spatial']}, {'question': 'There is a top-mid liver object; are there any bottom-right anatomys grasped by it?', 'answers': ['False', 'one_hop.json', 'exist', 'relate_actional']}, {'question': 'There is a top-mid liver thing; are there any anatomys below it?', 'answers': ['True', 'one_hop.json', 'exist', 'relate_spati ...

# %% [markdown]
# ## Compare tools

# %%
import csv

def parse_tool_annotations(file_path):
    tool_usage = {}
    with open(file_path, 'r', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile, delimiter='\t')
        for row in reader:
            frame_id = row['Frame']
            present_tools = [tool for tool, presence in row.items() if tool != 'Frame' and presence == '1']
            tool_usage[frame_id] = present_tools
    return tool_usage

# %%
def integrate_tools_into_unified_data(unified_data, video_id, tool_usage):
    for frame_id, tools in tool_usage.items():
        if video_id not in unified_data:
            unified_data[video_id] = {"annotations": {}}
        if frame_id not in unified_data[video_id]["annotations"]:
            unified_data[video_id]["annotations"][frame_id] = {"categories": {}, "qa": []}
        
        unified_data[video_id]["annotations"][frame_id]["tools"] = tools

    return unified_data

# %%
def display_frame_annotations(frame_data):
    print("    Categories:")
    for category, items in frame_data.get("categories", {}).items():
        items_str = ', '.join(str(item) for item in items if item is not None)
        print(f"      {category.capitalize()}: {items_str if items_str else 'N/A'}")
    
    phase = frame_data.get("phase", "N/A")
    print(f"    Phase: {phase}")

    if "tools" in frame_data:
        tools_str = ', '.join(frame_data["tools"])
        print("    Tools:")
        print(f"      {tools_str if tools_str else 'None'}")
    else:
        print("    Tools: N/A")

    # Display triplets if available
    if "triplets" in frame_data:
        print("    Triplets:")
        for triplet in frame_data["triplets"]:
            print(f"      {triplet}")
    else:
        print("    Triplets: N/A")

    if "qa" in frame_data:
        print("    Q&A:")
        for qa in frame_data["qa"]:
            print(f"      Question: {qa.get('question')}")
            for answer in qa.get("answers", []):
                print(f"        Answer: {answer}")
    print("")  # Adds an empty line for readability

# %%
tool_annotations_file = '/media/telecom/77F7-D47D/cholec80/tool_annotations/video01-tool.txt' 
tool_usage = parse_tool_annotations(tool_annotations_file)

unified_data = integrate_tools_into_unified_data(unified_data, "VID01", tool_usage)

display_annotations(unified_data, "VID01", "1100")
#print(type(unified_data))
#sorted(unified_data.keys())
# Out:
# Annotations for Video ID: VID01, Frame ID: 1100:
#     Categories:
#       Instruments: hook, grasper
#       Verbs: dissect, retract
#       Targets: gallbladder
#     Phase: CalotTriangleDissection
#     Tools:
#       Grasper, Hook
#     Triplets:
#       (hook, dissect, gallbladder)

# %%
def generate_triplets_from_frame(frame_data):
    instruments = frame_data.get("categories", {}).get("instruments", [])
    verbs = frame_data.get("categories", {}).get("verbs", [])
    targets = frame_data.get("categories", {}).get("targets", [])
    
    # Ensure there's an equal number of instruments, verbs, and targets
    # This might need adjustment based on how your data is structured
    triplets = list(zip(instruments, verbs, targets))
    return ["(" + ", ".join(triplet) + ")" for triplet in triplets]

# %%
def integrate_triplets_into_unified_data(unified_data):
    for video_id, video_data in unified_data.items():
        for frame_id, frame_data in video_data.get("annotations", {}).items():
            triplets = generate_triplets_from_frame(frame_data)
            frame_data["triplets"] = triplets
    return unified_data

# %%
unified_data = integrate_triplets_into_unified_data(unified_data)

# %%
with open(unified_json_file_path, 'w', encoding='utf-8') as file:
    json.dump(unified_data, file, indent=4)

# %% [markdown]
# ## Remove Duplicates

# %%
def remove_repetitions(unified_data):
    for video_id, video_data in unified_data.items():
        annotations = video_data.get("annotations", {})
        for frame_id, frame_data in annotations.items():
            categories = frame_data.get("categories", {})
            # Remove repetitions for instruments, verbs, and targets
            for category, items in categories.items():
                unique_items = list(set(items))  # Convert to set to remove duplicates, then back to list
                unified_data[video_id]["annotations"][frame_id]["categories"][category] = unique_items
            
            # Additionally, remove repetitions in triplets
            if "triplets" in frame_data:
                # Assuming triplets are strings and can be directly deduplicated using a set
                unique_triplets = list(set(frame_data["triplets"]))
                unified_data[video_id]["annotations"][frame_id]["triplets"] = unique_triplets

    return unified_data

# Assuming unified_data is your dataset loaded into a Python dictionary
# Apply the function to remove repetitions
unified_data = remove_repetitions(unified_data)

# Optionally, save the updated dataset back to a JSON file
with open(unified_json_file_path, 'w', encoding='utf-8') as file:
    json.dump(unified_data, file, indent=4)

print("Repetitions removed and dataset updated.")
# Out:
# Repetitions removed and dataset updated.
